# %% [markdown]
# ## introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
plt.show([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
plt.plot(x,y);

# %%
plt.show(x,y)

# %%
# %matplotlib inline

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 fig=plt.figure()
# ----> 2 ax=fig.add_axes()
#       3 plt.show()
#
# File ~\sample_project_1\env\Lib\site-packages\matplotlib\figure.py:618, in FigureBase.add_axes(self, *args, **kwargs)
#     533 """
#     534 Add an `~.axes.Axes` to the figure.
#     535
#    (...)    614     fig.add_axes(ax)
#     615 """
#     617 if not len(args) and 'rect' not in kwargs:
# --> 618     raise TypeError("add_axes() missing 1 required positional argument: 'rect'")
#     619 elif 'rect' in kwargs:
#     620     if len(args):
#
# TypeError: add_axes() missing 1 required positional argument: 'rect'

# %%
fig, ax=plt.subplots() 
ax.plot(x,y);
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
fig, ax= plt.subplots()
ax.plot(x, y);

# %%
plt.show(x,y)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[11,22,33,44]

fig, ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)

ax.set(title="simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

fig.savefig("images/sampleplot.png")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 40]

# Create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))  # 8x6 inches canvas

# Plotting the data
ax.plot(x, y, label="Sales", color='green', marker='o')

# Add labels and title
ax.set_title("Monthly Sales")       # Title
ax.set_xlabel("Month")              # X-axis label
ax.set_ylabel("Sales (in 1000s)")   # Y-axis label

# Add grid and legend
ax.grid(True)
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## making figures with numpy array
# *line plot
# *scater plot
# *bar plot
# *histogram
# *subplot

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)  # Correct function name is linspace, not linespace
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax=plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
fig, ax=plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
fig, ax= plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %%
#make a plot from dictionary
nut_butter_prices={"almond butter":10,
                   "peanut butter":8,
                   "cashew butter":12}
fig, ax=plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's nut butter store",
       ylabel="price $")
plt.show();

# %%
fig, ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
plt.show();

# %%
x=np.random.randn(1000)
fig, ax=plt.subplots()
ax.hist(x);
plt.show();

# %% [markdown]
# ### two option for subplot

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5));
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), (nut_butter_prices.values()));
ax4.hist(np.random.randn(1000));
plt.show();

# %%
#subplot option 2
fig, ax=plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10, 5));
#plot to each different axis
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[0,1].bar(nut_butter_prices.keys(), (nut_butter_prices.values()));
ax[0,1].hist(np.random.randn(1000));
plt.show();

# %% [markdown]
# ## PLOTING FROM PANDAS DATAFRAME

# %%
import pandas as pd

# %%
#make a dataframe
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
             index = pd.date_range("1/1/2020", periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000),
             index = pd.date_range("1/1/2020", periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(1000),
             index = pd.date_range("1/1/2020", periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.]', '', regex=True)
car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1576\4016968023.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.]', '', regex=True)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.]', '', regex=True)
car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1576\4016968023.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.]', '', regex=True)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]= car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["total sales"]= car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  total sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
#lets plot the total sale
car_sales.plot(x="Sale Date", y="total sales");

# %%
x=np.random.rand(10,4)
x
df=pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.210726  0.471228  0.398514  0.951859
# 1  0.224123  0.463420  0.251466  0.172643
# 2  0.075084  0.422516  0.465530  0.167574
# 3  0.527808  0.687435  0.711929  0.623112
# 4  0.493684  0.802468  0.312983  0.624534
# 5  0.230602  0.616152  0.366462  0.490291
# 6  0.490894  0.107031  0.246340  0.287927
# 7  0.683022  0.794142  0.262445  0.442887
# 8  0.873465  0.348125  0.116918  0.846261
# 9  0.114153  0.122894  0.799473  0.600708

# %%
df.plot.bar()
# Out:
# <Axes: >
